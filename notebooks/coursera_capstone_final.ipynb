# %% [markdown]
# # Cousera Capstone Final Project - Find Similar Neighborhood

# %%
# import packages
import pandas as pd

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1 Problem Description

# %% [markdown]
# Suppose someone is currently living in a neighborhood in **Toronto, ON, Canada**, and is moving to the Santa Clara County to starting her new career.
# Her new work address will be **1330 Geneva Dr, Sunnyvale, CA 94089**.
# She wants to find a similar neighborhood in the Santa Clara County to live in, but she would also weigh commute time.
# This project will help people who currently live in Toronto who will move to the Santa Clara County and wish to live in a similar neighborhood with reasonable commute time.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# **The neighborhood data of Santa Clara County** is available on https://www.sccgov.org/sites/phd/hi/hd/Pages/city-profiles.aspx to get all neighborhoods in Santa Clara County.
# For example, we can obtain Neighborhood name, the city name where the neighborhood is located from this data set.
#
# **Foursquares location data (Places API)** will be used to obtain neighborhood nearby venues data (for example, Venue Category) to find similar neighborhoods in Santa Clara County.
# **Google Maps Geocoding API** will be used to obtain coordinates (latitude and longitude) of the neighborhoods to feed into Foursquares Places API.
# **Google Maps Distance Matrix API** will be used to obtain the commute time from each neighborhood to her new work address.

# %% [markdown]
# ### A overview of neighborhood data

# %%
df_santa_clara = pd.read_excel('final-small-area-neighborhood-data-for-web.xls')
df_santa_clara.head(3)
# Out:
#        City                Neighborhood  Population Size  Race/Ethnicity  \
# 0  San Jose              Almaden Valley            28613             NaN
# 1  San Jose                   Alum Rock            23670             NaN
# 2  San Jose  Alum Rock / East Foothills             9309             NaN
#
#    African American  Asian/Pacific Islander  Latino  White  Foreign-born  \
# 0              0.01                    0.21    0.15   0.58          0.28
# 1              0.02                    0.41    0.47   0.08          0.54
# 2              0.03                    0.19    0.33   0.42          0.24
#
#    Speaks a language other than English at home  Single parent households  \
# 0                                          0.36                      0.07
# 1                                          0.78                      0.17
# 2                                          0.38                      0.07
#
#    Households with children  Average household size  Age Groups   0-5 years  \
# 0                      0.43                2.952857         NaN        0.07
# 1                      0.48                3.560000         NaN        0.10
# 2                      0.33                3.000000         NaN        0.07
#
#     6-11 years  12-17 years  18-24 years  25-34 years   35-44 years  \
# 0         0.10         0.10         0.06         0.07          0.15
# 1         0.09         0.08         0.10         0.16          0.14
# 2         0.07         0.07         0.08         0.11          0.13
#
#    45-54 years   55-64 years   Ages 65 and older  Median household income  \
# 0         0.18          0.12                0.15                   127204
# 1         0.13          0.10                0.10                    50172
# 2         0.17          0.14                0.15                   104155
#
#    Unemployed (ages ≥ 16 years)  Poverty  Families below 185% FPL  \
# 0                          0.04      NaN                     0.09
# 1                          0.08      NaN                     0.40
# 2                          0.05      NaN                     0.10
#
#    Children (ages 0-17) below 185% FPL  \
# 0                                 0.14
# 1                                 0.55
# 2                                 0.17
#
#    Children (ages 3-5) enrolled in preschool or nursery school  \
# 0                                               0.51
# 1                                               0.23
# 2                                               0.44
#
#    Educational attainment (ages ≥25)  Less than high school  \
# 0                                NaN                   0.06
# 1                                NaN                   0.34
# 2                                NaN                   0.13
#
#    High school graduate   Some college or associates degree  \
# 0                   0.12                               0.26
# 1                   0.26                               0.24
# 2                   0.18                               0.29
#
#    College graduate or higher  \
# 0                        0.56
# 1                        0.17
# 2                        0.40
#
#    Number of vehicle-pedestrian injury collisions, 10 years  \
# 0                                                 33
# 1                                                135
# 2                                                 11
#
#    Number of vehicle-bicycle injury collisions, 10 years  \
# 0                                                 47
# 1                                                102
# 2                                                 14
#
#    Number of motor vehicle collisions, 1 year   \
# 0                                           47
# 1                                          109
# 2                                           11
#
#    Lives within ½ mile of a regional bus/rail/ferry and within ¼ mile of bus/light rail  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    Percentage of residents who commute to work by mode  Drove alone  \
# 0                                                NaN           0.79
# 1                                                NaN           0.76
# 2                                                NaN           0.81
#
#    Carpooled  Public transportation  Other  \
# 0       0.09                   0.02   0.10
# 1       0.12                   0.07   0.06
# 2       0.05                   0.02   0.12
#
#    Households receiving CalFresh benefits  \
# 0                                    0.00
# 1                                    0.14
# 2                                    0.01
#
#    Average distance (miles) to nearest full-service grocery store   \
# 0                                           2.175714
# 1                                           0.583333
# 2                                           1.770000
#
#    Average distance (miles) to nearest farmers’ market  \
# 0                                           2.307880
# 1                                           1.720827
# 2                                           1.967254
#
#    Number of fast food outlets per square mile  \
# 0                                       1.6014
# 1                                       3.5337
# 2                                       0.1397
#
#    Households with gross rent 30% or more of household income  \
# 0                                               0.62
# 1                                               0.55
# 2                                               0.54
#
#    Overcrowded households  Lives in multi-unit housing  \
# 0                    0.03                         0.12
# 1                    0.24                         0.53
# 2                    0.05                         0.06
#
#    Average distance (miles) to nearest park or open space    \
# 0                                           0.233461
# 1                                           0.166138
# 2                                           0.472141
#
#    Number of tobacco retail outlets per square mile  \
# 0                                            3.0025
# 1                                           15.9015
# 2                                            0.1397
#
#    Average number of violent crimes within 1 mile   \
# 0                                         3.354286
# 1                                        32.880000
# 2                                         3.620000
#
#    Number of alcohol retail outlets per square mile  \
# 0                                            2.6022
# 1                                           10.1593
# 2                                            0.1397
#
#    Maternal, child and infant health   Births per 1,000 people  \
# 0                                NaN                    7.4675
# 1                                NaN                   15.7020
# 2                                NaN                   10.7423
#
#    Low birth weight infants  Preterm births  \
# 0                      0.06            0.08
# 1                      0.07            0.11
# 2                      0.05            0.10
#
#    Overweight or obese in first trimester of pregnancy  \
# 0                                               0.36
# 1                                               0.50
# 2                                               0.46
#
#    Mothers who received early and adequate prenatal care  \
# 0                                               0.82
# 1                                               0.69
# 2                                               0.69
#
#    Teen live births per 1,000 females, ages 15-19  Mortality Life expectancy  \
# 0                                          8.9903        NaN         84.3255
# 1                                         43.0490        NaN          82.938
# 2                                         25.2324        NaN         83.8465
#
#   Cancer deaths per 100,000 people Heart disease deaths per 100,000 people  \
# 0                          119.561                                 125.474
# 1                          131.299                                 113.522
# 2                          136.396                                  131.64
#
#   Alzheimer’s disease deaths per 100,000 people  \
# 0                                       27.1714
# 1                                       47.8295
# 2                                       36.7919
#
#   Stroke deaths per 100,000 people  \
# 0                          21.0522
# 1                          28.2585
# 2                               --
#
#   Chronic lower respiratory disease deaths per 100,000 people  \
# 0                                            22.9304
# 1                                            23.7045
# 2                                                 --
#
#   Unintentional injury deaths per 100,000 people  \
# 0                                        15.0997
# 1                                        20.8876
# 2                                             --
#
#   Diabetes deaths per 100,000 people  \
# 0                            21.2062
# 1                             36.819
# 2                                 --
#
#   Influenza and pneumonia deaths per 100,000 people  \
# 0                                                --
# 1                                                --
# 2                                                --
#
#   Hypertension deaths per 100,000 people
# 0                                17.9124
# 1                                20.6205
# 2                                     --

# %% [markdown]
# In this project, we will only use **City** and **Neighborhood** from this data set
